# %%
import pandas as pd
from video import Video
import datetime
from run import row_to_video, update_row_from_video

# %%
db_path = "../db/"
csv_file = "fact_videos.csv"

# %%
df = pd.read_csv(db_path + csv_file)
df["post_date"] = pd.to_datetime(df["post_date"])
df["created_at"] = pd.to_datetime(df["created_at"])
df["uploaded_at"] = pd.to_datetime(df["uploaded_at"])
df.index = df["id"]

# %%
df
# Out:
#     id  post_date created_at uploaded_at              music_file  \
# id
# 1    1 2023-01-01        NaT         NaT  blade_runner_synth.mp3
# 2    2        NaT        NaT         NaT                     NaN
# 3    3        NaT        NaT         NaT                     NaN
# 4    4        NaT        NaT         NaT                     NaN
# 5    5        NaT        NaT         NaT                     NaN
# 6    6        NaT        NaT         NaT                     NaN
# 7    7        NaT        NaT         NaT                     NaN
# 8    8        NaT        NaT         NaT                     NaN
# 9    9        NaT        NaT         NaT                     NaN
#
#                                        background_url  \
# id
# 1   https://www.pexels.com/video/a-sunset-time-lap...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
#
#                                 title                          description  \
# id
# 1   Fun facts you need to know #facts  Comment which one is your favorite.
# 2                                 NaN                                  NaN
# 3                                 NaN                                  NaN
# 4                                 NaN                                  NaN
# 5                                 NaN                                  NaN
# 6                                 NaN                                  NaN
# 7                                 NaN                                  NaN
# 8                                 NaN                                  NaN
# 9                                 NaN                                  NaN
#
#                          tags                                  text1  \
# id
# 1   facts, crazy, cool, funny  Crazy facts you need to know (part 1)
# 2                         NaN                                    NaN
# 3                         NaN                                    NaN
# 4                         NaN                                    NaN
# 5                         NaN                                    NaN
# 6                         NaN                                    NaN
# 7                         NaN                                    NaN
# 8                         NaN                                    NaN
# 9                         NaN                                    NaN
#
#                                                 text2  \
# id
# 1   Potato chips cause more weight gain than any o...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
#
#                                                 text3  \
# id
# 1   Our brains make up on average 2% of our body w...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
#
#                                                 text4  text5  text6
# id
# 1   If a bee consumes alcohol and gets drunk, he w...    NaN    NaN
# 2                                                 NaN    NaN    NaN
# 3                                                 NaN    NaN    NaN
# 4                                                 NaN    NaN    NaN
# 5                                                 NaN    NaN    NaN
# 6                                                 NaN    NaN    NaN
# 7                                                 NaN    NaN    NaN
# 8                                                 NaN    NaN    NaN
# 9                                                 NaN    NaN    NaN

# %%
non_empty_df = df[~(pd.isnull(df["background_url"]) | pd.isnull(df["title"]) | pd.isnull(df["post_date"]) | pd.isnull(df["music_file"]))]
non_empty_df
# Out:
#     id  post_date created_at uploaded_at              music_file  \
# id
# 1    1 2023-01-01        NaT         NaT  blade_runner_synth.mp3
#
#                                        background_url  \
# id
# 1   https://www.pexels.com/video/a-sunset-time-lap...
#
#                                 title                          description  \
# id
# 1   Fun facts you need to know #facts  Comment which one is your favorite.
#
#                          tags                                  text1  \
# id
# 1   facts, crazy, cool, funny  Crazy facts you need to know (part 1)
#
#                                                 text2  \
# id
# 1   Potato chips cause more weight gain than any o...
#
#                                                 text3  \
# id
# 1   Our brains make up on average 2% of our body w...
#
#                                                 text4  text5  text6
# id
# 1   If a bee consumes alcohol and gets drunk, he w...    NaN    NaN

# %%
row = df.iloc[0]
row.index
# Out:
# Index(['id', 'post_date', 'created_at', 'uploaded_at', 'music_file',
#        'background_url', 'title', 'description', 'tags', 'text1', 'text2',
#        'text3', 'text4', 'text5', 'text6'],
#       dtype='object')

# %%
row
# Out:
# id                                                                1
# post_date                                       2023-01-01 00:00:00
# created_at                                                      NaT
# uploaded_at                                                     NaT
# music_file                                   blade_runner_synth.mp3
# background_url    https://www.pexels.com/video/a-sunset-time-lap...
# title                             Fun facts you need to know #facts
# description                     Comment which one is your favorite.
# tags                                      facts, crazy, cool, funny
# text1                         Crazy facts you need to know (part 1)
# text2             Potato chips cause more weight gain than any o...
# text3             Our brains make up on average 2% of our body w...
# text4             If a bee consumes alcohol and gets drunk, he w...
# text5                                                           NaN
# text6                                                           NaN
# Name: 1, dtype: object

# %%
row["post_date"].to_pydatetime()
# Out:
# datetime.datetime(2023, 1, 1, 0, 0)

# %%
video1 = row_to_video(row)

# %%
print(video1)
# Out:
# {'id': 1, 'post_date': datetime.datetime(2023, 1, 1, 0, 0), 'created_at': None, 'uploaded_at': None, 'music_file': 'blade_runner_synth.mp3', 'background_url': 'https://www.pexels.com/video/a-sunset-time-lapse-8035714/', 'background_file': '', 'video_file': 'video_1.mp4', 'content': {'title': 'Fun facts you need to know #facts', 'description': 'Comment which one is your favorite.', 'tags': ['facts,crazy,cool,funny'], 'texts': ['Crazy facts you need to know (part 1)', 'Potato chips cause more weight gain than any other food', 'Our brains make up on average 2% of our body weight but consume 20% of our caloric intake', "If a bee consumes alcohol and gets drunk, he won’t be let back into the hive until he's sober."]}}

# %%
video1.get_bg_clip_pexels()
# Out:
# a-sunset-time-lapse-8035714.mp4 already downloaded

# %%
video1.create_video(save_video=False)
# Out:
# music duration: 56.08s
# Retrieved background clip:
# Width: 1080, Height 1920, fps: 25.0, orig duration: 12.24s
# text clip duration 27.8
# final_clip duration 27.8

# %%
print(video1)
# Out:
# {'id': 1, 'post_date': datetime.datetime(2023, 1, 1, 0, 0), 'created_at': None, 'uploaded_at': None, 'music_file': 'blade_runner_synth.mp3', 'background_url': 'https://www.pexels.com/video/a-sunset-time-lapse-8035714/', 'background_file': 'a-sunset-time-lapse-8035714.mp4', 'video_file': 'video_1.mp4', 'content': {'title': 'Fun facts you need to know #facts', 'description': 'Comment which one is your favorite.', 'tags': ['facts,crazy,cool,funny'], 'texts': ['Crazy facts you need to know (part 1)', 'Potato chips cause more weight gain than any other food', 'Our brains make up on average 2% of our body weight but consume 20% of our caloric intake', "If a bee consumes alcohol and gets drunk, he won’t be let back into the hive until he's sober."]}}

# %%
df.index
# Out:
# Int64Index([1, 2, 3, 4, 5, 6, 7, 8, 9], dtype='int64', name='id')

# %%
update_row_from_video(df, video1)

# %%
df
# Out:
#     id  post_date created_at uploaded_at              music_file  \
# id
# 1    1 2023-01-01        NaT         NaT  blade_runner_synth.mp3
# 2    2        NaT        NaT         NaT                     NaN
# 3    3        NaT        NaT         NaT                     NaN
# 4    4        NaT        NaT         NaT                     NaN
# 5    5        NaT        NaT         NaT                     NaN
# 6    6        NaT        NaT         NaT                     NaN
# 7    7        NaT        NaT         NaT                     NaN
# 8    8        NaT        NaT         NaT                     NaN
# 9    9        NaT        NaT         NaT                     NaN
#
#                                        background_url  \
# id
# 1   https://www.pexels.com/video/a-sunset-time-lap...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
#
#                                 title                          description  \
# id
# 1   Fun facts you need to know #facts  Comment which one is your favorite.
# 2                                 NaN                                  NaN
# 3                                 NaN                                  NaN
# 4                                 NaN                                  NaN
# 5                                 NaN                                  NaN
# 6                                 NaN                                  NaN
# 7                                 NaN                                  NaN
# 8                                 NaN                                  NaN
# 9                                 NaN                                  NaN
#
#                          tags                                  text1  \
# id
# 1   facts, crazy, cool, funny  Crazy facts you need to know (part 1)
# 2                         NaN                                    NaN
# 3                         NaN                                    NaN
# 4                         NaN                                    NaN
# 5                         NaN                                    NaN
# 6                         NaN                                    NaN
# 7                         NaN                                    NaN
# 8                         NaN                                    NaN
# 9                         NaN                                    NaN
#
#                                                 text2  \
# id
# 1   Potato chips cause more weight gain than any o...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
#
#                                                 text3  \
# id
# 1   Our brains make up on average 2% of our body w...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
#
#                                                 text4  text5  text6
# id
# 1   If a bee consumes alcohol and gets drunk, he w...    NaN    NaN
# 2                                                 NaN    NaN    NaN
# 3                                                 NaN    NaN    NaN
# 4                                                 NaN    NaN    NaN
# 5                                                 NaN    NaN    NaN
# 6                                                 NaN    NaN    NaN
# 7                                                 NaN    NaN    NaN
# 8                                                 NaN    NaN    NaN
# 9                                                 NaN    NaN    NaN

# %%
df.to_csv(db_path + csv_file, index = False)

# %%
df1= pd.read_csv(db_path + csv_file)
df1["post_date"] = pd.to_datetime(df1["post_date"])
df1["created_at"] = pd.to_datetime(df1["created_at"])
df1["uploaded_at"] = pd.to_datetime(df1["uploaded_at"])
df1.index = df1["id"]
df1
# Out:
#     id  post_date created_at uploaded_at              music_file  \
# id
# 1    1 2023-01-01        NaT         NaT  blade_runner_synth.mp3
# 2    2        NaT        NaT         NaT                     NaN
# 3    3        NaT        NaT         NaT                     NaN
# 4    4        NaT        NaT         NaT                     NaN
# 5    5        NaT        NaT         NaT                     NaN
# 6    6        NaT        NaT         NaT                     NaN
# 7    7        NaT        NaT         NaT                     NaN
# 8    8        NaT        NaT         NaT                     NaN
# 9    9        NaT        NaT         NaT                     NaN
#
#                                        background_url  \
# id
# 1   https://www.pexels.com/video/a-sunset-time-lap...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
#
#                                 title                          description  \
# id
# 1   Fun facts you need to know #facts  Comment which one is your favorite.
# 2                                 NaN                                  NaN
# 3                                 NaN                                  NaN
# 4                                 NaN                                  NaN
# 5                                 NaN                                  NaN
# 6                                 NaN                                  NaN
# 7                                 NaN                                  NaN
# 8                                 NaN                                  NaN
# 9                                 NaN                                  NaN
#
#                          tags                                  text1  \
# id
# 1   facts, crazy, cool, funny  Crazy facts you need to know (part 1)
# 2                         NaN                                    NaN
# 3                         NaN                                    NaN
# 4                         NaN                                    NaN
# 5                         NaN                                    NaN
# 6                         NaN                                    NaN
# 7                         NaN                                    NaN
# 8                         NaN                                    NaN
# 9                         NaN                                    NaN
#
#                                                 text2  \
# id
# 1   Potato chips cause more weight gain than any o...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
#
#                                                 text3  \
# id
# 1   Our brains make up on average 2% of our body w...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
#
#                                                 text4  text5  text6
# id
# 1   If a bee consumes alcohol and gets drunk, he w...    NaN    NaN
# 2                                                 NaN    NaN    NaN
# 3                                                 NaN    NaN    NaN
# 4                                                 NaN    NaN    NaN
# 5                                                 NaN    NaN    NaN
# 6                                                 NaN    NaN    NaN
# 7                                                 NaN    NaN    NaN
# 8                                                 NaN    NaN    NaN
# 9                                                 NaN    NaN    NaN

# %%
video1.upload_to_youtube()
# Out:
# Successfully authenticated into Youtube API
# scheduled for scheduled_ts.isoformat()
# Uploading file...
# A retriable HTTP error 500 occurred:
# b'{\n  "error": {\n    "code": 500,\n    "message": "Internal error encountered.",\n    "errors": [\n      {\n        "message": "Missing content owner id.",\n        "domain": "youtube.api.v3.RequestContextError",\n        "reason": "ERROR_CONTENT_OWNER_CHANNEL_WITHOUT_CONTENT_OWNER"\n      }\n    ],\n    "status": "INTERNAL"\n  }\n}\n'
# Sleeping 0.865582 seconds and then retrying...
# Uploading file...
# A retriable HTTP error 500 occurred:
# b'{\n  "error": {\n    "code": 500,\n    "message": "Internal error encountered.",\n    "errors": [\n      {\n        "message": "Missing content owner id.",\n        "domain": "youtube.api.v3.RequestContextError",\n        "reason": "ERROR_CONTENT_OWNER_CHANNEL_WITHOUT_CONTENT_OWNER"\n      }\n    ],\n    "status": "INTERNAL"\n  }\n}\n'
# Sleeping 0.015136 seconds and then retrying...
# Uploading file...
# A retriable HTTP error 500 occurred:
# b'{\n  "error": {\n    "code": 500,\n    "message": "Internal error encountered.",\n    "errors": [\n      {\n        "message": "Missing content owner id.",\n        "domain": "youtube.api.v3.RequestContextError",\n        "reason": "ERROR_CONTENT_OWNER_CHANNEL_WITHOUT_CONTENT_OWNER"\n      }\n    ],\n    "status": "INTERNAL"\n  }\n}\n'
# Sleeping 4.866244 seconds and then retrying...
# Uploading file...
# A retriable HTTP error 500 occurred:
# b'{\n  "error": {\n    "code": 500,\n    "message": "Internal error encountered.",\n    "errors": [\n      {\n        "message": "Missing content owner id.",\n        "domain": "youtube.api.v3.RequestContextError",\n        "reason": "ERROR_CONTENT_OWNER_CHANNEL_WITHOUT_CONTENT_OWNER"\n      }\n    ],\n    "status": "INTERNAL"\n  }\n}\n'
# Sleeping 8.304796 seconds and then retrying...
# Uploading file...
# ---------------------------------------------------------------------------
# ResumableUploadError                      Traceback (most recent call last)
# <ipython-input-23-35c37ffd8cec> in <module>()
# ----> 1 video1.upload_to_youtube()
#
# /Users/rohanmirchandani/Desktop/Automation/src/video.py in upload_to_youtube(self, schedule)
#     229
#     230                 # Execute the request
# --> 231                 response = upload_video.resumable_upload(request)
#     232                 self.uploaded_at = datetime.now().replace(second=0, microsecond=0)
#     233                 print(f"Uploaded video title: {title}")
#
# /Users/rohanmirchandani/Desktop/Automation/src/upload_video.py in resumable_upload(insert_request)
#     139     try:
#     140       print("Uploading file...")
# --> 141       status, response = insert_request.next_chunk()
#     142       if response is not None:
#     143         if 'id' in response:
#
# /Users/rohanmirchandani/anaconda/lib/python3.6/site-packages/googleapiclient/_helpers.py in positional_wrapper(*args, **kwargs)
#     128                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129                     logger.warning(message)
# --> 130             return wrapped(*args, **kwargs)
#     131
#     132         return positional_wrapper
#
# /Users/rohanmirchandani/anaconda/lib/python3.6/site-packages/googleapiclient/http.py in next_chunk(self, http, num_retries)
#    1020                 self.resumable_uri = resp["location"]
#    1021             else:
# -> 1022                 raise ResumableUploadError(resp, content)
#    1023         elif self._in_error_state:
#    1024             # If we are in an error state then query the server for current state of
#
# ResumableUploadError: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">

# %%
video1.uploaded_at

# %%
import os
os.path.exists("../clips/video_1.mp4")
# Out:
# True
