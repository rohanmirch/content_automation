# %%
import string
import random
import os
import pprint

# %% [markdown]
# ### Download Youtube video

# %%
from pytube import YouTube

# %%
# Use the YouTube class to fetch the video
yt = YouTube("https://www.youtube.com/watch?v=2A9vLlClbYc&t=317s")
title = yt.title
print(f"Retrieved {title}")
stream = yt.streams.filter(progressive=True).get_highest_resolution()
print(f"Best video stream: {stream}")
# Out:
# Retrieved Neymar Jr Best Skills With Commentary / Crowd Reaction
# Best video stream: <Stream: itag="22" mime_type="video/mp4" res="720p" fps="25fps" vcodec="avc1.64001F" acodec="mp4a.40.2" progressive="True" type="video">

# %%
# Use the get method of the video object to fetch the video
video_file = title.translate(str.maketrans("","",string.punctuation)).replace(" ", "_") + ".mp4"
#stream.download(output_path = "../media", filename = video_file)

print("Downloaded {}".format("../media/{}".format(video_file)))
# Out:
# Downloaded ../media/Neymar_Jr_Best_Skills_With_Commentary__Crowd_Reaction.mp4

# %%
video_path = f"../media/{video_file}"
print("video_path:   {}".format(video_path))
# Out:
# video_path:   ../media/Neymar_Jr_Best_Skills_With_Commentary__Crowd_Reaction.mp4

# %% [markdown]
#  ### Blur

# %%
import numpy as np
import moviepy.editor as mpy
import moviepy.video.fx as fx
from moviepy.video.VideoClip import ImageClip
import cv2
import skimage.filters

print("np version {}".format(np.__version__))
print("cv2 version {}".format(cv2.__version__))
print("skimage version {}".format(skimage.__version__))
# Out:
# np version 1.19.5
# cv2 version 4.1.2
# skimage version 0.17.2

# %%
# Open the video file
clip = mpy.VideoFileClip(video_path)
fps = clip.fps
width, height = clip.size
print(f"Width: {width}, Height {height}, fps: {fps}")
# Out:
# Width: 1280, Height 720, fps: 25.0

# %%
# Calculate blur pixels from watermark from screenshot
sc_size = (1219, 688)
top_left = (115,468)
bottom_right = (175, 487)
def calculate_blur_region(video_size, sc_size, top_left, bottom_right):
    x1 = top_left[0]/sc_size[0]*video_size[0]
    x2 = bottom_right[0]/sc_size[0]*video_size[0]
    y1 = top_left[1]/sc_size[1]*video_size[1]
    y2 = bottom_right[1]/sc_size[1]*video_size[1]
    return int(x1), int(x2), int(y1), int(y2)

x1, x2, y1, y2 = calculate_blur_region((width, height), sc_size, top_left, bottom_right)
print("x1: {}, x2: {}, y1: {}, y2: {}".format(x1, x2, y1, y2))
# Out:
# x1: 120, x2: 183, y1: 489, y2: 509

# %%
# Edit the file

# Define a function to apply the blur filter
def blur_region(image):
    x1, x2, y1, y2 = calculate_blur_region((width, height), sc_size, top_left, bottom_right)

    img_copy = image.copy()
    # img_copy[y1:y2, x1:x2] = skimage.filters.gaussian(image[y1:y2, x1:x2], sigma=3)
    img_copy[y1:y2, x1:x2] = cv2.GaussianBlur(image[y1:y2, x1:x2], (11,11), cv2.BORDER_DEFAULT)
    
    return img_copy

# Apply the blur filter to the video
blurred_clip = clip.fl_image(blur_region)

# Crop clip
blurred_clip = fx.all.crop(blurred_clip, x2 = 1130)

# Display a clip
blurred_clip.ipython_display(t = 10, width = 600)
# Out:
# <div align=middle><img width='600' src='data:image/png;base64,...'></div>

# %%
# Play subclip

# getting only first 3 seconds
subclip = blurred_clip.subclip(8, 11)

# Display clip in notebook
# subclip.ipython_display(width = 480, fps = 15)

# Display external interactive image
# blurred_clip.show(11, interactive = True)
  
# Externally previewing the subclip at fps = 20
# subclip.preview(fps = 20)

# %%
# Save the output video file
# blurred_clip.write_videofile(f"../media/blurred_mpy_{video_file}")

# %%
subclip_times = [
    ("0:11", "0:17"),
    ("0:28", "0:43"),
    ("0:44", "0:52"),
    ("0:53", "1:05"),
    ("1:06", "1:14"),
    ("1:35", "1:42"),
    ("1:43", "1:56"),
    ("1:57", "2:07"),
    ("2:08", "2:20"),
    ("2:41", "2:57"),
]
def convert_ts_to_sec(ts):
    ts = ts.split(":")
    return int(ts[0])*60 + int(ts[1])


subclip_times = [(convert_ts_to_sec(s[0]), convert_ts_to_sec(s[1])) for s in subclip_times]
subclip_times
# Out:
# [(11, 17),
#  (28, 43),
#  (44, 52),
#  (53, 65),
#  (66, 74),
#  (95, 102),
#  (103, 116),
#  (117, 127),
#  (128, 140),
#  (161, 177)]

# %%
# Get full video 
# video_clip = blurred_clip
video_clip = mpy.VideoFileClip(f"../media/blurred_mpy_{video_file}")
fps = video_clip.fps
width, height = video_clip.size
print(f"Width: {width}, Height {height}, fps: {fps}")
# Out:
# Width: 1130, Height 720, fps: 25.0

# %%
from moviepy.audio.fx.all import *

music_path = "../audio/"
music_file = "parado_no_bailaio.m4a"
music = mpy.AudioFileClip(music_path + music_file)
# music.preview()

# %%
# Get background
final_size = (900, 1600)
bg = ImageClip("../media/images/neymar_wallpaper.jpeg")
bg = bg.resize(final_size)
bg = bg.set_duration(1)
#bg.preview()

# %%
# Create subclips
from moviepy.video.compositing.CompositeVideoClip import *

subclips = []
for start, end in subclip_times:
    subclip = video_clip.subclip(start,end)
    duration = subclip.duration
    
    # Add music
    music_clip = music.fx(volumex, 0.5).fx(audio_fadein, 1)
    new_audioclip = mpy.CompositeAudioClip([subclip.audio.fx(volumex, 2), music_clip])
    new_audioclip = new_audioclip.set_duration(duration).set_fps(44100)
    subclip = subclip.set_audio(new_audioclip)
    
    # Resize
    # Crop clip
    subclip = fx.all.crop(subclip, x2 = 1080)
    subclip = subclip.resize(width = final_size[0])
    s_size, s_width = subclip.size
    
    #Layer over backgroud
    #//subclip_top_pos = final_size[1]/2
    subclip = subclip.set_position(("center",  "center" ))
    subclip = CompositeVideoClip([bg, subclip], use_bgclip = True).set_audio(new_audioclip)
    
    subclips.append(subclip)
    
print(subclips)
# Out:
# [<moviepy.video.compositing.CompositeVideoClip.CompositeVideoClip object at 0x7fa6bcf9a518>, <moviepy.video.compositing.CompositeVideoClip.CompositeVideoClip object at 0x7fa6bcf9aeb8>, <moviepy.video.compositing.CompositeVideoClip.CompositeVideoClip object at 0x7fa6bcf9d2e8>, <moviepy.video.compositing.CompositeVideoClip.CompositeVideoClip object at 0x7fa6bcf9d828>, <moviepy.video.compositing.CompositeVideoClip.CompositeVideoClip object at 0x7fa6cfbf1240>, <moviepy.video.compositing.CompositeVideoClip.CompositeVideoClip object at 0x7fa6bcf6c780>, <moviepy.video.compositing.CompositeVideoClip.CompositeVideoClip object at 0x7fa6bcf6c160>, <moviepy.video.compositing.CompositeVideoClip.CompositeVideoClip object at 0x7fa6bcf6c978>, <moviepy.video.compositing.CompositeVideoClip.CompositeVideoClip object at 0x7fa6d57142b0>, <moviepy.video.compositing.CompositeVideoClip.CompositeVideoClip object at 0x7fa6d5fd2198>]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-83-dc9ed458bdfd> in <module>()
# ----> 1 subclip.height
#
# AttributeError: 'CompositeVideoClip' object has no attribute 'height'

# %%
# Display clip in notebook

# subclips[0].audio.preview()

# subclips[0].ipython_display(width = 480, fps = 15)
  
# Externally previewing the subclip at fps = 20, pick a random subclip
random_index = random.choice(range(len(subclips)))
subclips[random_index].preview(fps = 20)
# Out:
# time, position, color :  1.000, (12, 1440), [54 39 30]
# time, position, color :  1.000, (12, 1440), [54 39 30]
# time, position, color :  1.000, (12, 1440), [54 39 30]
# time, position, color :  1.000, (12, 1440), [54 39 30]
# time, position, color :  1.000, (12, 1440), [54 39 30]
# time, position, color :  1.000, (12, 1440), [54 39 30]
# time, position, color :  1.000, (12, 1440), [54 39 30]
# time, position, color :  1.000, (12, 1440), [54 39 30]
# time, position, color :  1.050, (12, 1440), [54 39 30]
# time, position, color :  1.050, (12, 1440), [54 39 30]
# time, position, color :  1.050, (12, 1440), [54 39 30]
# time, position, color :  1.050, (12, 1440), [54 39 30]
# time, position, color :  1.050, (12, 1440), [54 39 30]
# time, position, color :  1.050, (12, 1440), [54 39 30]
# time, position, color :  1.050, (12, 1440), [54 39 30]
# time, position, color :  1.050, (12, 1440), [54 39 30]
# time, position, color :  1.050, (12, 1440), [54 39 30]
# time, position, color :  1.050, (12, 1440), [54 39 30]
# time, position, color :  1.050, (12, 1440), [54 39 30]
# time, position, color :  1.050, (12, 1440), [54 39 30]
# time, position, color :  1.050, (12, 1440), [54 39 30]
# time, position, color :  1.050, (12, 1440), [54 39 30]
# time, position, color :  1.050, (12, 1440), [54 39 30]
# time, position, color :  1.050, (12, 1440), [54 39 30]
# time, position, color :  1.100, (12, 1440), [54 39 30]
# time, position, color :  1.100, (12, 1440), [54 39 30]
# time, position, color :  1.100, (12, 1440), [54 39 30]
# time, position, color :  1.100, (12, 1440), [54 39 30]
# time, position, color :  1.100, (12, 1440), [54 39 30]
# time, position, color :  1.100, (12, 1440), [54 39 30]
# time, position, color :  1.100, (12, 1440), [54 39 30]
# time, position, color :  1.150, (12, 1440), [54 39 30]
# time, position, color :  1.150, (12, 1440), [54 39 30]
# time, position, color :  1.200, (12, 1440), [54 39 30]
# time, position, color :  10.350, (539, 368), [58 31 14]
# time, position, color :  10.350, (539, 368), [58 31 14]
# time, position, color :  10.350, (539, 368), [58 31 14]
# time, position, color :  10.350, (539, 368), [58 31 14]
# time, position, color :  10.350, (539, 368), [58 31 14]
# time, position, color :  10.400, (539, 368), [58 31 14]
# time, position, color :  10.400, (539, 368), [58 31 14]
# time, position, color :  10.400, (539, 368), [58 31 14]
# time, position, color :  10.400, (539, 368), [58 31 14]
# time, position, color :  10.400, (539, 368), [58 31 14]
# time, position, color :  10.400, (539, 368), [58 31 14]
# time, position, color :  10.400, (539, 368), [58 31 14]
# time, position, color :  10.400, (539, 368), [58 31 14]
# time, position, color :  10.450, (539, 368), [58 31 14]
# time, position, color :  10.450, (539, 368), [58 31 14]
# time, position, color :  10.450, (539, 368), [58 31 14]
# time, position, color :  10.450, (539, 368), [58 31 14]
# time, position, color :  10.450, (539, 368), [58 31 14]
# time, position, color :  10.500, (539, 368), [58 31 14]
# time, position, color :  10.500, (539, 368), [58 31 14]
# time, position, color :  10.500, (539, 368), [58 31 14]
# time, position, color :  10.500, (539, 368), [58 31 14]
# time, position, color :  10.550, (539, 368), [58 31 14]

# %%
# Save subclips
only_save_first = False
for i, clip in enumerate(subclips):
    if only_save_first:
        if i > 0:
            break
    clip.write_videofile(f"../clips/clip{i}_{video_file}", audio_codec='aac')
# Out:
# t:   1%|▏         | 2/150 [19:25<00:21,  7.02it/s, now=None]
# chunk:   0%|          | 0/133 [00:00<?, ?it/s, now=None]
# chunk:   2%|▏         | 2/133 [00:00<00:07, 17.51it/s, now=None]
# Moviepy - Building video ../clips/clip0_Neymar_Jr_Best_Skills_With_Commentary__Crowd_Reaction.mp4.
# MoviePy - Writing audio in clip0_Neymar_Jr_Best_Skills_With_Commentary__Crowd_ReactionTEMP_MPY_wvf_snd.mp4
# chunk:  77%|███████▋  | 102/133 [00:00<00:01, 24.81it/s, now=None]
# t:   1%|▏         | 2/150 [19:25<00:21,  7.02it/s, now=None]
# t:   0%|          | 0/150 [00:00<?, ?it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ../clips/clip0_Neymar_Jr_Best_Skills_With_Commentary__Crowd_Reaction.mp4
# t:   1%|▏         | 2/150 [00:00<00:20,  7.32it/s, now=None]
# t:   6%|▌         | 9/150 [00:00<00:14, 10.01it/s, now=None]
# t:  11%|█▏        | 17/150 [00:00<00:09, 13.51it/s, now=None]
# t:  16%|█▌        | 24/150 [00:00<00:07, 17.65it/s, now=None]
# t:  21%|██        | 31/150 [00:00<00:05, 22.44it/s, now=None]
# t:  26%|██▌       | 39/150 [00:00<00:03, 28.30it/s, now=None]
# t:  31%|███       | 46/150 [00:00<00:03, 34.42it/s, now=None]
# t:  35%|███▌      | 53/150 [00:01<00:02, 39.29it/s, now=None]
# t:  39%|███▉      | 59/150 [00:01<00:02, 31.32it/s, now=None]
# t:  43%|████▎     | 64/150 [00:01<00:02, 30.59it/s, now=None]
# t:  46%|████▌     | 69/150 [00:01<00:02, 29.57it/s, now=None]
# t:  49%|████▊     | 73/150 [00:01<00:02, 28.92it/s, now=None]
# t:  51%|█████▏    | 77/150 [00:01<00:02, 27.96it/s, now=None]
# t:  54%|█████▍    | 81/150 [00:02<00:02, 27.62it/s, now=None]
# t:  57%|█████▋    | 85/150 [00:02<00:02, 27.95it/s, now=None]
# t:  59%|█████▉    | 89/150 [00:02<00:02, 28.27it/s, now=None]
# t:  61%|██████▏   | 92/150 [00:02<00:02, 26.89it/s, now=None]
# t:  63%|██████▎   | 95/150 [00:02<00:02, 25.57it/s, now=None]
# t:  66%|██████▌   | 99/150 [00:02<00:02, 25.41it/s, now=None]
# t:  69%|██████▊   | 103/150 [00:02<00:01, 27.07it/s, now=None]
# t:  71%|███████   | 106/150 [00:03<00:01, 26.90it/s, now=None]
# t:  73%|███████▎  | 109/150 [00:03<00:01, 27.62it/s, now=None]
# t:  75%|███████▍  | 112/150 [00:03<00:01, 27.24it/s, now=None]
# t:  77%|███████▋  | 116/150 [00:03<00:01, 28.14it/s, now=None]
# t:  79%|███████▉  | 119/150 [00:03<00:01, 27.49it/s, now=None]
# t:  81%|████████▏ | 122/150 [00:03<00:01, 27.25it/s, now=None]
# t:  83%|████████▎ | 125/150 [00:03<00:01, 24.89it/s, now=None]
# t:  86%|████████▌ | 129/150 [00:03<00:00, 26.22it/s, now=None]
# t:  89%|████████▊ | 133/150 [00:04<00:00, 25.79it/s, now=None]
# t:  91%|█████████▏| 137/150 [00:04<00:00, 25.83it/s, now=None]
# t:  93%|█████████▎| 140/150 [00:04<00:00, 26.90it/s, now=None]
# t:  95%|█████████▌| 143/150 [00:04<00:00, 25.84it/s, now=None]
# t:  97%|█████████▋| 146/150 [00:04<00:00, 26.00it/s, now=None]
# t:  99%|█████████▉| 149/150 [00:04<00:00, 23.65it/s, now=None]
# t:   1%|▏         | 2/150 [19:31<00:21,  7.02it/s, now=None]
# chunk:   0%|          | 0/331 [00:00<?, ?it/s, now=None]
# chunk:   8%|▊         | 28/331 [00:00<00:01, 279.96it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready ../clips/clip0_Neymar_Jr_Best_Skills_With_Commentary__Crowd_Reaction.mp4
# Moviepy - Building video ../clips/clip1_Neymar_Jr_Best_Skills_With_Commentary__Crowd_Reaction.mp4.
# MoviePy - Writing audio in clip1_Neymar_Jr_Best_Skills_With_Commentary__Crowd_ReactionTEMP_MPY_wvf_snd.mp4
# chunk:  26%|██▋       | 87/331 [00:00<00:00, 332.27it/s, now=None]
# chunk:  56%|█████▌    | 186/331 [00:00<00:00, 414.75it/s, now=None]
# chunk:  90%|█████████ | 298/331 [00:00<00:00, 511.29it/s, now=None]
# t:   1%|▏         | 2/150 [19:32<00:21,  7.02it/s, now=None]
# t:   0%|          | 0/375 [00:00<?, ?it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ../clips/clip1_Neymar_Jr_Best_Skills_With_Commentary__Crowd_Reaction.mp4
# t:   1%|          | 2/375 [00:00<00:34, 10.95it/s, now=None]
# t:   2%|▏         | 7/375 [00:00<00:25, 14.28it/s, now=None]
# t:   3%|▎         | 13/375 [00:00<00:19, 18.33it/s, now=None]
# t:   5%|▌         | 19/375 [00:00<00:15, 22.94it/s, now=None]
# t:   7%|▋         | 27/375 [00:00<00:11, 29.07it/s, now=None]
# t:   9%|▉         | 35/375 [00:00<00:09, 35.49it/s, now=None]
# t:  11%|█         | 42/375 [00:00<00:08, 40.89it/s, now=None]
# t:  13%|█▎        | 48/375 [00:00<00:07, 45.05it/s, now=None]
# t:  14%|█▍        | 54/375 [00:01<00:06, 46.73it/s, now=None]
# t:  16%|█▌        | 60/375 [00:01<00:10, 30.60it/s, now=None]
# t:  17%|█▋        | 65/375 [00:01<00:10, 30.31it/s, now=None]
# t:  90%|████████▉ | 337/375 [00:12<00:01, 24.57it/s, now=None]
# t:  91%|█████████ | 340/375 [00:12<00:01, 23.45it/s, now=None]
# t:  91%|█████████▏| 343/375 [00:12<00:01, 24.93it/s, now=None]
# t:  92%|█████████▏| 346/375 [00:12<00:01, 23.59it/s, now=None]
# t:  93%|█████████▎| 349/375 [00:13<00:01, 22.96it/s, now=None]
# t:  94%|█████████▍| 352/375 [00:13<00:01, 21.27it/s, now=None]
# t:  95%|█████████▍| 355/375 [00:13<00:00, 21.33it/s, now=None]
# t:  95%|█████████▌| 358/375 [00:13<00:00, 19.91it/s, now=None]
# t:  96%|█████████▋| 361/375 [00:13<00:00, 21.85it/s, now=None]
# t:  97%|█████████▋| 364/375 [00:13<00:00, 19.73it/s, now=None]
# t:  98%|█████████▊| 367/375 [00:14<00:00, 19.11it/s, now=None]
# t:  99%|█████████▉| 371/375 [00:14<00:00, 21.84it/s, now=None]
# t: 100%|█████████▉| 374/375 [00:14<00:00, 20.54it/s, now=None]
# t:   1%|▏         | 2/150 [19:48<00:21,  7.02it/s, now=None]
# chunk:   0%|          | 0/177 [00:00<?, ?it/s, now=None]
# chunk:  19%|█▊        | 33/177 [00:00<00:00, 329.55it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready ../clips/clip1_Neymar_Jr_Best_Skills_With_Commentary__Crowd_Reaction.mp4
# Moviepy - Building video ../clips/clip2_Neymar_Jr_Best_Skills_With_Commentary__Crowd_Reaction.mp4.
# MoviePy - Writing audio in clip2_Neymar_Jr_Best_Skills_With_Commentary__Crowd_ReactionTEMP_MPY_wvf_snd.mp4
# chunk:  72%|███████▏  | 127/177 [00:00<00:00, 409.27it/s, now=None]
# t:   1%|▏         | 2/150 [19:48<00:21,  7.02it/s, now=None]
# t:   0%|          | 0/200 [00:00<?, ?it/s, now=None]
# t:   2%|▏         | 3/200 [00:00<00:07, 27.38it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ../clips/clip2_Neymar_Jr_Best_Skills_With_Commentary__Crowd_Reaction.mp4
# t:   5%|▌         | 10/200 [00:00<00:05, 33.31it/s, now=None]
# t:  10%|▉         | 19/200 [00:00<00:04, 40.74it/s, now=None]
# t:  14%|█▍        | 28/200 [00:00<00:03, 48.09it/s, now=None]
# t:  18%|█▊        | 37/200 [00:00<00:02, 54.86it/s, now=None]
# t:  22%|██▎       | 45/200 [00:00<00:02, 59.59it/s, now=None]
# t:  26%|██▋       | 53/200 [00:00<00:02, 62.86it/s, now=None]
# t:  30%|███       | 60/200 [00:01<00:03, 39.95it/s, now=None]
# t:  33%|███▎      | 66/200 [00:01<00:03, 37.12it/s, now=None]
# t:  36%|███▌      | 71/200 [00:01<00:03, 32.85it/s, now=None]
# t:  38%|███▊      | 76/200 [00:01<00:03, 32.36it/s, now=None]
# t:  40%|████      | 80/200 [00:01<00:03, 33.56it/s, now=None]
# t:  42%|████▏     | 84/200 [00:01<00:03, 30.58it/s, now=None]
# t:  44%|████▍     | 88/200 [00:02<00:03, 30.42it/s, now=None]
# t:  46%|████▌     | 92/200 [00:02<00:03, 31.19it/s, now=None]
# t:  48%|████▊     | 96/200 [00:02<00:03, 29.93it/s, now=None]
# t:  50%|█████     | 100/200 [00:02<00:03, 29.15it/s, now=None]
# t:  52%|█████▏    | 104/200 [00:02<00:03, 29.73it/s, now=None]
# t:  54%|█████▍    | 108/200 [00:02<00:03, 24.71it/s, now=None]
# t:  56%|█████▋    | 113/200 [00:02<00:03, 26.36it/s, now=None]
# t:  58%|█████▊    | 116/200 [00:03<00:03, 26.90it/s, now=None]
# t:  60%|█████▉    | 119/200 [00:03<00:03, 26.38it/s, now=None]
# t:  61%|██████    | 122/200 [00:03<00:03, 24.34it/s, now=None]
# t:  62%|██████▎   | 125/200 [00:03<00:02, 25.68it/s, now=None]
# t:  64%|██████▍   | 128/200 [00:03<00:02, 26.22it/s, now=None]
# t:  66%|██████▌   | 131/200 [00:03<00:02, 26.21it/s, now=None]
# t:  67%|██████▋   | 134/200 [00:03<00:02, 24.35it/s, now=None]
# t:  68%|██████▊   | 137/200 [00:04<00:03, 19.73it/s, now=None]
# t:  70%|███████   | 141/200 [00:04<00:02, 21.90it/s, now=None]
# t:  72%|███████▎  | 145/200 [00:04<00:02, 23.16it/s, now=None]
# t:  74%|███████▍  | 149/200 [00:04<00:02, 23.12it/s, now=None]
# t:  76%|███████▋  | 153/200 [00:04<00:01, 24.48it/s, now=None]
# t:  78%|███████▊  | 157/200 [00:04<00:01, 24.39it/s, now=None]
# t:  80%|████████  | 161/200 [00:04<00:01, 24.97it/s, now=None]
# t:  82%|████████▎ | 165/200 [00:05<00:01, 24.63it/s, now=None]
# t:  84%|████████▍ | 169/200 [00:05<00:01, 24.83it/s, now=None]
# t:  86%|████████▌ | 172/200 [00:05<00:01, 25.21it/s, now=None]
# t:  88%|████████▊ | 175/200 [00:05<00:01, 23.85it/s, now=None]
# t:  89%|████████▉ | 178/200 [00:05<00:00, 23.50it/s, now=None]
# t:  90%|█████████ | 181/200 [00:05<00:00, 23.59it/s, now=None]
# t:  92%|█████████▎| 185/200 [00:05<00:00, 23.57it/s, now=None]
# t:  94%|█████████▍| 189/200 [00:06<00:00, 23.65it/s, now=None]
# t:  96%|█████████▋| 193/200 [00:06<00:00, 24.13it/s, now=None]
# t:  98%|█████████▊| 197/200 [00:06<00:00, 23.95it/s, now=None]
# t:   1%|▏         | 2/150 [19:56<00:21,  7.02it/s, now=None]
# chunk:   0%|          | 0/265 [00:00<?, ?it/s, now=None]
# chunk:  22%|██▏       | 57/265 [00:00<00:00, 567.14it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready ../clips/clip2_Neymar_Jr_Best_Skills_With_Commentary__Crowd_Reaction.mp4
# Moviepy - Building video ../clips/clip3_Neymar_Jr_Best_Skills_With_Commentary__Crowd_Reaction.mp4.
# MoviePy - Writing audio in clip3_Neymar_Jr_Best_Skills_With_Commentary__Crowd_ReactionTEMP_MPY_wvf_snd.mp4
# chunk:  60%|██████    | 160/265 [00:00<00:00, 655.16it/s, now=None]
# chunk:  96%|█████████▌| 255/265 [00:00<00:00, 720.31it/s, now=None]
# t:   1%|▏         | 2/150 [19:57<00:21,  7.02it/s, now=None]
# t:   0%|          | 0/300 [00:00<?, ?it/s, now=None]
# t:   1%|          | 2/300 [00:00<00:17, 17.52it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing
# t:  62%|██████▏   | 186/300 [00:05<00:03, 29.10it/s, now=None]
# t:  63%|██████▎   | 190/300 [00:05<00:03, 28.38it/s, now=None]
# t:  65%|██████▍   | 194/300 [00:05<00:03, 29.77it/s, now=None]
# t:  66%|██████▌   | 198/300 [00:05<00:03, 27.57it/s, now=None]
# t:  67%|██████▋   | 202/300 [00:06<00:03, 28.34it/s, now=None]
# t:  69%|██████▊   | 206/300 [00:06<00:03, 27.40it/s, now=None]
# t:  70%|███████   | 210/300 [00:06<00:03, 26.93it/s, now=None]
# t:  71%|███████▏  | 214/300 [00:06<00:03, 26.63it/s, now=None]
# t:  73%|███████▎  | 218/300 [00:06<00:02, 27.44it/s, now=None]
# t:  74%|███████▍  | 222/300 [00:06<00:02, 26.83it/s, now=None]
# t:  75%|███████▌  | 226/300 [00:07<00:02, 26.86it/s, now=None]
# t:  77%|███████▋  | 230/300 [00:07<00:02, 25.99it/s, now=None]
# t:  78%|███████▊  | 234/300 [00:07<00:02, 26.29it/s, now=None]
# t:  79%|███████▉  | 238/300 [00:07<00:02, 26.87it/s, now=None]
# t:  81%|████████  | 242/300 [00:07<00:02, 24.98it/s, now=None]
# t:  82%|████████▏ | 246/300 [00:07<00:01, 27.09it/s, now=None]
# t:  83%|████████▎ | 249/300 [00:07<00:02, 24.99it/s, now=None]
# t:  84%|████████▍ | 252/300 [00:08<00:01, 25.02it/s, now=None]
# t:  85%|████████▌ | 255/300 [00:08<00:01, 23.71it/s, now=None]
# t:  86%|████████▌ | 258/300 [00:08<00:01, 24.05it/s, now=None]
# t:  87%|████████▋ | 261/300 [00:08<00:01, 23.04it/s, now=None]
# t:  88%|████████▊ | 264/300 [00:08<00:01, 24.25it/s, now=None]
# t:  89%|████████▉ | 267/300 [00:08<00:01, 24.45it/s, now=None]
# t:  90%|█████████ | 270/300 [00:08<00:01, 24.43it/s, now=None]
# t:  91%|█████████▏| 274/300 [00:08<00:01, 25.32it/s, now=None]
# t:  93%|█████████▎| 278/300 [00:09<00:00, 26.30it/s, now=None]
# t:  94%|█████████▍| 282/300 [00:09<00:00, 26.40it/s, now=None]
# t:  95%|█████████▌| 286/300 [00:09<00:00, 26.84it/s, now=None]
# t:  97%|█████████▋| 290/300 [00:09<00:00, 28.66it/s, now=None]
# t:  98%|█████████▊| 294/300 [00:09<00:00, 30.55it/s, now=None]
# t:  99%|█████████▉| 298/300 [00:09<00:00, 28.33it/s, now=None]
# t:   1%|▏         | 2/150 [20:08<00:21,  7.02it/s, now=None]
# chunk:   0%|          | 0/177 [00:00<?, ?it/s, now=None]
# chunk:  31%|███       | 54/177 [00:00<00:00, 539.67it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready ../clips/clip3_Neymar_Jr_Best_Skills_With_Commentary__Crowd_Reaction.mp4
# Moviepy - Building video ../clips/clip4_Neymar_Jr_Best_Skills_With_Commentary__Crowd_Reaction.mp4.
# MoviePy - Writing audio in clip4_Neymar_Jr_Best_Skills_With_Commentary__Crowd_ReactionTEMP_MPY_wvf_snd.mp4
# chunk:  93%|█████████▎| 165/177 [00:00<00:00, 637.48it/s, now=None]
# t:   1%|▏         | 2/150 [20:08<00:21,  7.02it/s, now=None]
# t:   0%|          | 0/200 [00:00<?, ?it/s, now=None]
# t:   2%|▏         | 3/200 [00:00<00:07, 26.54it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ../clips/clip4_Neymar_Jr_Best_Skills_With_Commentary__Crowd_Reaction.mp4
# t:   6%|▌         | 11/200 [00:00<00:05, 33.14it/s, now=None]
# t:  10%|█         | 20/200 [00:00<00:04, 40.64it/s, now=None]
# t:  14%|█▍        | 28/200 [00:00<00:03, 47.68it/s, now=None]
# t:  18%|█▊        | 36/200 [00:00<00:03, 54.08it/s, now=None]
# t:  22%|██▏       | 44/200 [00:00<00:02, 59.73it/s, now=None]
# t:  26%|██▌       | 52/200 [00:00<00:02, 62.78it/s, now=None]
# t:  30%|██▉       | 59/200 [00:01<00:03, 42.91it/s, now=None]
# t:  32%|███▎      | 65/200 [00:01<00:03, 38.66it/s, now=None]
# t:  35%|███▌      | 70/200 [00:01<00:03, 34.73it/s, now=None]
# t:  38%|███▊      | 75/200 [00:01<00:03, 33.97it/s, now=None]
# t:  40%|███▉      | 79/200 [00:01<00:03, 32.54it/s, now=None]
# t:  42%|████▏     | 83/200 [00:01<00:03, 33.29it/s, now=None]
# t:  44%|████▍     | 88/200 [00:01<00:03, 33.16it/s, now=None]
# t:  46%|████▌     | 92/200 [00:02<00:03, 32.34it/s, now=None]
# t:  48%|████▊     | 96/200 [00:02<00:03, 30.53it/s, now=None]
# t:  50%|█████     | 100/200 [00:02<00:03, 31.60it/s, now=None]
# t:  52%|█████▏    | 104/200 [00:02<00:03, 31.47it/s, now=None]
# t:  54%|█████▍    | 108/200 [00:02<00:02, 30.98it/s, now=None]
# t:  56%|█████▌    | 112/200 [00:02<00:02, 31.26it/s, now=None]
# t:  58%|█████▊    | 116/200 [00:02<00:02, 30.82it/s, now=None]
# t:  60%|██████    | 120/200 [00:02<00:02, 31.91it/s, now=None]
# t:  62%|██████▏   | 124/200 [00:03<00:02, 30.95it/s, now=None]
# t:  64%|██████▍   | 128/200 [00:03<00:02, 29.53it/s, now=None]
# t:  66%|██████▌   | 131/200 [00:03<00:02, 27.51it/s, now=None]
# t:  68%|██████▊   | 136/200 [00:03<00:02, 31.06it/s, now=None]
# t:  70%|███████   | 140/200 [00:03<00:01, 30.87it/s, now=None]
# t:  72%|███████▏  | 144/200 [00:03<00:01, 31.26it/s, now=None]
# t:  74%|███████▍  | 148/200 [00:03<00:01, 30.56it/s, now=None]
# t:  76%|███████▌  | 152/200 [00:04<00:01, 30.30it/s, now=None]
# t:  78%|███████▊  | 156/200 [00:04<00:01, 30.23it/s, now=None]
# t:  80%|████████  | 160/200 [00:04<00:01, 28.15it/s, now=None]
# t:  82%|████████▏ | 163/200 [00:04<00:01, 26.60it/s, now=None]
# t:  83%|████████▎ | 166/200 [00:04<00:01, 27.25it/s, now=None]
# t:  84%|████████▍ | 169/200 [00:04<00:01, 25.89it/s, now=None]
# t:  86%|████████▋ | 173/200 [00:04<00:01, 26.90it/s, now=None]
# t:  88%|████████▊ | 176/200 [00:04<00:00, 26.31it/s, now=None]
# t:  90%|█████████ | 180/200 [00:05<00:00, 27.36it/s, now=None]
# t:  92%|█████████▏| 183/200 [00:05<00:00, 25.87it/s, now=None]
# t:  94%|█████████▎| 187/200 [00:05<00:00, 27.62it/s, now=None]
# t:  96%|█████████▌| 191/200 [00:05<00:00, 26.70it/s, now=None]
# t:  98%|█████████▊| 195/200 [00:05<00:00, 27.32it/s, now=None]
# t: 100%|█████████▉| 199/200 [00:05<00:00, 26.81it/s, now=None]
# t:   1%|▏         | 2/150 [20:16<00:21,  7.02it/s, now=None]
# chunk:   0%|          | 0/155 [00:00<?, ?it/s, now=None]
# chunk:   8%|▊         | 12/155 [00:00<00:01, 119.92it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready ../clips/clip4_Neymar_Jr_Best_Skills_With_Commentary__Crowd_Reaction.mp4
# Moviepy - Building video ../clips/clip5_Neymar_Jr_Best_Skills_With_Commentary__Crowd_Reaction.mp4.
# MoviePy - Writing audio in clip5_Neymar_Jr_Best_Skills_With_Commentary__Crowd_ReactionTEMP_MPY_wvf_snd.mp4
# chunk:  78%|███████▊  | 121/155 [00:00<00:00, 163.57it/s, now=None]
# t:   1%|▏         | 2/150 [20:16<00:21,  7.02it/s, now=None]
# t:   0%|          | 0/175 [00:00<?, ?it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ../clips/clip5_Neymar_Jr_Best_Skills_With_Commentary__Crowd_Reaction.mp4
# t:   1%|          | 2/175 [00:00<00:20,  8.57it/s, now=None]
# t:   6%|▌         | 10/175 [00:00<00:14, 11.69it/s, now=None]
# t:  10%|█         | 18/175 [00:00<00:09, 15.71it/s, now=None]
# t:  15%|█▍        | 26/175 [00:00<00:07, 20.63it/s, now=None]
# t:  19%|█▉        | 34/175 [00:00<00:05, 26.49it/s, now=None]
# t:  24%|██▍       | 42/175 [00:00<00:04, 32.70it/s, now=None]
# t:  29%|██▊       | 50/175 [00:00<00:03, 39.55it/s, now=None]
# t:  33%|███▎      | 57/175 [00:01<00:03, 35.19it/s, now=None]
# t:  36%|███▌      | 63/175 [00:01<00:03, 33.32it/s, now=None]
# t:  39%|███▉      | 68/175 [00:01<00:03, 33.10it/s, now=None]
# t:  42%|████▏     | 73/175 [00:01<00:02, 35.74it/s, now=None]
# t:  45%|████▍     | 78/175 [00:01<00:02, 35.67it/s, now=None]
# t:  47%|████▋     | 83/175 [00:01<00:02, 33.56it/s, now=None]
# t:  50%|████▉     | 87/175 [00:02<00:02, 32.91it/s, now=None]
# t:  52%|█████▏    | 91/175 [00:02<00:02, 34.05it/s, now=None]
# t:  54%|█████▍    | 95/175 [00:02<00:02, 33.58it/s, now=None]
# t:  57%|█████▋    | 99/175 [00:02<00:02, 32.15it/s, now=None]
# t:  59%|█████▉    | 103/175 [00:02<00:02, 31.14it/s, now=None]
# t:  61%|██████    | 107/175 [00:02<00:02, 31.04it/s, now=None]
# t:  63%|██████▎   | 111/175 [00:02<00:01, 33.17it/s, now=None]
# t:  66%|██████▌   | 115/175 [00:02<00:02, 29.81it/s, now=None]
# t:  68%|██████▊   | 119/175 [00:03<00:01, 28.84it/s, now=None]
# t:  70%|███████   | 123/175 [00:03<00:01, 30.04it/s, now=None]
# t:  73%|███████▎  | 127/175 [00:03<00:01, 29.42it/s, now=None]
# t:  75%|███████▍  | 131/175 [00:03<00:01, 27.98it/s, now=None]
# t:  77%|███████▋  | 135/175 [00:03<00:01, 28.49it/s, now=None]
# t:  79%|███████▉  | 139/175 [00:03<00:01, 29.01it/s, now=None]
# t:  82%|████████▏ | 143/175 [00:03<00:01, 29.77it/s, now=None]
# t:  84%|████████▍ | 147/175 [00:04<00:00, 28.77it/s, now=None]
# t:  86%|████████▋ | 151/175 [00:04<00:00, 30.13it/s, now=None]
# t:  89%|████████▊ | 155/175 [00:04<00:00, 29.58it/s, now=None]
# t:  91%|█████████ | 159/175 [00:04<00:00, 29.36it/s, now=None]
# t:  93%|█████████▎| 163/175 [00:04<00:00, 29.97it/s, now=None]
# t:  95%|█████████▌| 167/175 [00:04<00:00, 29.11it/s, now=None]
# t:  98%|█████████▊| 171/175 [00:04<00:00, 27.04it/s, now=None]
# t: 100%|██████████| 175/175 [00:05<00:00, 27.75it/s, now=None]
# t:   1%|▏         | 2/150 [20:22<00:21,  7.02it/s, now=None]
# chunk:   0%|          | 0/287 [00:00<?, ?it/s, now=None]
# chunk:  24%|██▍       | 70/287 [00:00<00:00, 699.08it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready ../clips/clip5_Neymar_Jr_Best_Skills_With_Commentary__Crowd_Reaction.mp4
# Moviepy - Building video ../clips/clip6_Neymar_Jr_Best_Skills_With_Commentary__Crowd_Reaction.mp4.
# MoviePy - Writing audio in clip6_Neymar_Jr_Best_Skills_With_Commentary__Crowd_ReactionTEMP_MPY_wvf_snd.mp4
# chunk:  60%|█████▉    | 171/287 [00:00<00:00, 769.60it/s, now=None]
# t:   1%|▏         | 2/150 [20:23<00:21,  7.02it/s, now=None]
# t:   0%|          | 0/325 [00:00<?, ?it/s, now=None]
# t:   1%|          | 3/325 [00:00<00:11, 27.42it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ../clips/clip6_Neymar_Jr_Best_Skills_With_Commentary__Crowd_Reaction.mp4
# t:   3%|▎         | 11/325 [00:00<00:09, 33.81it/s, now=None]
# t:   6%|▌         | 20/325 [00:00<00:07, 41.27it/s, now=None]
# t:   9%|▉         | 29/325 [00:00<00:06, 48.49it/s, now=None]
# t:  12%|█▏        | 38/325 [00:00<00:05, 55.38it/s, now=None]
# t:  14%|█▍        | 46/325 [00:00<00:04, 59.73it/s, now=None]
# t:  16%|█▋        | 53/325 [00:00<00:04, 62.44it/s, now=None]
# t:  18%|█▊        | 60/325 [00:01<00:05, 44.19it/s, now=None]
# t:  20%|██        | 66/325 [00:01<00:06, 39.64it/s, now=None]
# t:  22%|██▏       | 71/325 [00:01<00:06, 36.66it/s, now=None]
# t:  23%|██▎       | 76/325 [00:01<00:06, 38.99it/s, now=None]
# t:  25%|██▍       | 81/325 [00:01<00:06, 37.44it/s, now=None]
# t:  26%|██▋       | 86/325 [00:01<00:06, 36.51it/s, now=None]
# t:  28%|██▊       | 90/325 [00:01<00:06, 37.09it/s, now=None]
# t:  74%|███████▎  | 239/325 [00:07<00:03, 23.58it/s, now=None]
# t:  74%|███████▍  | 242/325 [00:07<00:03, 23.75it/s, now=None]
# t:  75%|███████▌  | 245/325 [00:07<00:03, 24.00it/s, now=None]
# t:  76%|███████▋  | 248/325 [00:07<00:03, 22.27it/s, now=None]
# t:  78%|███████▊  | 252/325 [00:07<00:03, 24.08it/s, now=None]
# t:  78%|███████▊  | 255/325 [00:07<00:02, 23.55it/s, now=None]
# t:  79%|███████▉  | 258/325 [00:08<00:02, 23.26it/s, now=None]
# t:  81%|████████  | 262/325 [00:08<00:02, 23.28it/s, now=None]
# t:  82%|████████▏ | 265/325 [00:08<00:02, 22.98it/s, now=None]
# t:  82%|████████▏ | 268/325 [00:08<00:02, 24.40it/s, now=None]
# t:  83%|████████▎ | 271/325 [00:08<00:02, 23.24it/s, now=None]
# t:  84%|████████▍ | 274/325 [00:08<00:02, 21.09it/s, now=None]
# t:  85%|████████▌ | 277/325 [00:08<00:02, 23.00it/s, now=None]
# t:  86%|████████▌ | 280/325 [00:09<00:02, 21.16it/s, now=None]
# t:  87%|████████▋ | 283/325 [00:09<00:01, 22.44it/s, now=None]
# t:  88%|████████▊ | 286/325 [00:09<00:01, 22.32it/s, now=None]
# t:  89%|████████▉ | 289/325 [00:09<00:01, 23.65it/s, now=None]
# t:  90%|████████▉ | 292/325 [00:09<00:01, 22.17it/s, now=None]
# t:  91%|█████████ | 295/325 [00:09<00:01, 22.51it/s, now=None]
# t:  92%|█████████▏| 298/325 [00:09<00:01, 22.06it/s, now=None]
# t:  93%|█████████▎| 302/325 [00:09<00:00, 25.01it/s, now=None]
# t:  94%|█████████▍| 305/325 [00:10<00:00, 22.64it/s, now=None]
# t:  95%|█████████▌| 309/325 [00:10<00:00, 24.32it/s, now=None]
# t:  96%|█████████▌| 312/325 [00:10<00:00, 23.31it/s, now=None]
# t:  97%|█████████▋| 316/325 [00:10<00:00, 25.49it/s, now=None]
# t:  98%|█████████▊| 319/325 [00:10<00:00, 23.36it/s, now=None]
# t:  99%|█████████▉| 323/325 [00:10<00:00, 25.69it/s, now=None]
# t:   1%|▏         | 2/150 [20:35<00:21,  7.02it/s, now=None]
# chunk:   0%|          | 0/221 [00:00<?, ?it/s, now=None]
# chunk:  31%|███       | 68/221 [00:00<00:00, 679.58it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready ../clips/clip6_Neymar_Jr_Best_Skills_With_Commentary__Crowd_Reaction.mp4
# Moviepy - Building video ../clips/clip7_Neymar_Jr_Best_Skills_With_Commentary__Crowd_Reaction.mp4.
# MoviePy - Writing audio in clip7_Neymar_Jr_Best_Skills_With_Commentary__Crowd_ReactionTEMP_MPY_wvf_snd.mp4
# chunk:  74%|███████▍  | 164/221 [00:00<00:00, 744.48it/s, now=None]
# t:   1%|▏         | 2/150 [20:35<00:21,  7.02it/s, now=None]
# t:   0%|          | 0/250 [00:00<?, ?it/s, now=None]
# t:   1%|          | 3/250 [00:00<00:09, 26.75it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ../clips/clip7_Neymar_Jr_Best_Skills_With_Commentary__Crowd_Reaction.mp4
# t:   4%|▍         | 10/250 [00:00<00:07, 32.81it/s, now=None]
# t:   8%|▊         | 19/250 [00:00<00:05, 40.39it/s, now=None]
# t:  11%|█         | 28/250 [00:00<00:04, 48.04it/s, now=None]
# t:  15%|█▍        | 37/250 [00:00<00:03, 54.82it/s, now=None]
# t:  18%|█▊        | 45/250 [00:00<00:03, 59.09it/s, now=None]
# t:  21%|██        | 53/250 [00:00<00:03, 61.83it/s, now=None]
# t:  24%|██▍       | 60/250 [00:01<00:04, 41.52it/s, now=None]
# t:  26%|██▋       | 66/250 [00:01<00:04, 37.82it/s, now=None]
# t:  28%|██▊       | 71/250 [00:01<00:04, 37.63it/s, now=None]
# t:  30%|███       | 76/250 [00:01<00:05, 34.64it/s, now=None]
# t:  32%|███▏      | 80/250 [00:01<00:04, 35.34it/s, now=None]
# t:  34%|███▎      | 84/250 [00:01<00:04, 33.41it/s, now=None]
# t:  35%|███▌      | 88/250 [00:01<00:04, 34.70it/s, now=None]
# t:  37%|███▋      | 92/250 [00:02<00:04, 32.86it/s, now=None]
# t:  38%|███▊      | 96/250 [00:02<00:04, 32.91it/s, now=None]
# t:  40%|████      | 100/250 [00:02<00:04, 33.82it/s, now=None]
# t:  42%|████▏     | 104/250 [00:02<00:04, 29.86it/s, now=None]
# t:  43%|████▎     | 108/250 [00:02<00:04, 32.30it/s, now=None]
# t:  45%|████▍     | 112/250 [00:02<00:04, 31.17it/s, now=None]
# t:  46%|████▋     | 116/250 [00:02<00:04, 31.04it/s, now=None]
# t:  48%|████▊     | 120/250 [00:02<00:04, 31.45it/s, now=None]
# t:  50%|████▉     | 124/250 [00:03<00:03, 31.60it/s, now=None]
# t:  51%|█████     | 128/250 [00:03<00:03, 31.72it/s, now=None]
# t:  53%|█████▎    | 132/250 [00:03<00:03, 30.33it/s, now=None]
# t:  54%|█████▍    | 136/250 [00:03<00:03, 28.83it/s, now=None]
# t:  56%|█████▌    | 140/250 [00:03<00:03, 29.39it/s, now=None]
# t:  58%|█████▊    | 145/250 [00:03<00:03, 31.84it/s, now=None]
# t:  60%|█████▉    | 149/250 [00:03<00:03, 31.88it/s, now=None]
# t:  61%|██████    | 153/250 [00:03<00:02, 33.10it/s, now=None]
# t:  63%|██████▎   | 157/250 [00:04<00:02, 31.82it/s, now=None]
# t:  64%|██████▍   | 161/250 [00:04<00:02, 31.68it/s, now=None]
# t:  66%|██████▌   | 165/250 [00:04<00:02, 32.99it/s, now=None]
# t:  68%|██████▊   | 169/250 [00:04<00:02, 33.15it/s, now=None]
# t:  69%|██████▉   | 173/250 [00:04<00:02, 32.73it/s, now=None]
# t:  71%|███████   | 177/250 [00:04<00:02, 32.17it/s, now=None]
# t:  72%|███████▏  | 181/250 [00:04<00:02, 31.08it/s, now=None]
# t:  74%|███████▍  | 185/250 [00:04<00:02, 30.42it/s, now=None]
# t:  76%|███████▌  | 189/250 [00:05<00:02, 29.28it/s, now=None]
# t:  77%|███████▋  | 192/250 [00:05<00:02, 25.89it/s, now=None]
# t:  78%|███████▊  | 195/250 [00:05<00:02, 25.52it/s, now=None]
# t:  80%|███████▉  | 199/250 [00:05<00:02, 25.24it/s, now=None]
# t:  81%|████████  | 203/250 [00:05<00:01, 24.99it/s, now=None]
# t:  83%|████████▎ | 207/250 [00:05<00:01, 25.39it/s, now=None]
# t:  84%|████████▍ | 210/250 [00:06<00:01, 25.63it/s, now=None]
# t:  85%|████████▌ | 213/250 [00:06<00:01, 25.98it/s, now=None]
# t:  86%|████████▋ | 216/250 [00:06<00:01, 23.13it/s, now=None]
# t:  88%|████████▊ | 219/250 [00:06<00:01, 22.54it/s, now=None]
# t:  89%|████████▉ | 222/250 [00:06<00:01, 19.37it/s, now=None]
# t:  90%|█████████ | 226/250 [00:06<00:01, 21.27it/s, now=None]
# t:  92%|█████████▏| 229/250 [00:06<00:00, 23.17it/s, now=None]
# t:  93%|█████████▎| 232/250 [00:07<00:00, 23.01it/s, now=None]
# t:  94%|█████████▍| 235/250 [00:07<00:00, 23.26it/s, now=None]
# t:  95%|█████████▌| 238/250 [00:07<00:00, 22.95it/s, now=None]
# t:  97%|█████████▋| 242/250 [00:07<00:00, 23.05it/s, now=None]
# t:  98%|█████████▊| 246/250 [00:07<00:00, 24.57it/s, now=None]
# t: 100%|██████████| 250/250 [00:07<00:00, 24.93it/s, now=None]
# t:   1%|▏         | 2/150 [20:44<00:21,  7.02it/s, now=None]
# chunk:   0%|          | 0/265 [00:00<?, ?it/s, now=None]
# chunk:  20%|█▉        | 52/265 [00:00<00:00, 507.63it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready ../clips/clip7_Neymar_Jr_Best_Skills_With_Commentary__Crowd_Reaction.mp4
# Moviepy - Building video ../clips/clip8_Neymar_Jr_Best_Skills_With_Commentary__Crowd_Reaction.mp4.
# MoviePy - Writing audio in clip8_Neymar_Jr_Best_Skills_With_Commentary__Crowd_ReactionTEMP_MPY_wvf_snd.mp4
# chunk:  65%|██████▍   | 171/265 [00:00<00:00, 612.59it/s, now=None]
# t:   1%|▏         | 2/150 [20:45<00:21,  7.02it/s, now=None]
# t:   0%|          | 0/300 [00:00<?, ?it/s, now=None]
# t:   1%|          | 3/300 [00:00<00:10, 27.49it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ../clips/clip8_Neymar_Jr_Best_Skills_With_Commentary__Crowd_Reaction.mp4
# t:   4%|▎         | 11/300 [00:00<00:08, 34.07it/s, now=None]
# t:   7%|▋         | 20/300 [00:00<00:06, 41.60it/s, now=None]
# t:  10%|▉         | 29/300 [00:00<00:05, 48.76it/s, now=None]
# t:  13%|█▎        | 38/300 [00:00<00:04, 55.42it/s, now=None]
# t:  15%|█▌        | 45/300 [00:00<00:04, 59.08it/s, now=None]
# t:  18%|█▊        | 53/300 [00:00<00:03, 62.44it/s, now=None]
# t:  20%|██        | 60/300 [00:01<00:06, 38.71it/s, now=None]
# t:  22%|██▏       | 66/300 [00:01<00:07, 32.00it/s, now=None]
# t:  24%|██▎       | 71/300 [00:01<00:07, 30.69it/s, now=None]
# t:  25%|██▌       | 75/300 [00:01<00:07, 28.18it/s, now=None]
# t:  26%|██▋       | 79/300 [00:01<00:07, 29.21it/s, now=None]
# t:  74%|███████▍  | 222/300 [00:07<00:02, 27.54it/s, now=None]
# t:  75%|███████▌  | 226/300 [00:07<00:03, 24.07it/s, now=None]
# t:  77%|███████▋  | 230/300 [00:07<00:02, 26.47it/s, now=None]
# t:  78%|███████▊  | 233/300 [00:08<00:02, 24.07it/s, now=None]
# t:  79%|███████▊  | 236/300 [00:08<00:02, 24.77it/s, now=None]
# t:  80%|███████▉  | 239/300 [00:08<00:02, 22.94it/s, now=None]
# t:  81%|████████  | 242/300 [00:08<00:02, 24.41it/s, now=None]
# t:  82%|████████▏ | 245/300 [00:08<00:02, 22.57it/s, now=None]
# t:  83%|████████▎ | 249/300 [00:08<00:02, 24.81it/s, now=None]
# t:  84%|████████▍ | 252/300 [00:08<00:02, 23.83it/s, now=None]
# t:  85%|████████▌ | 256/300 [00:09<00:01, 24.39it/s, now=None]
# t:  86%|████████▋ | 259/300 [00:09<00:01, 25.25it/s, now=None]
# t:  87%|████████▋ | 262/300 [00:09<00:01, 24.83it/s, now=None]
# t:  88%|████████▊ | 265/300 [00:09<00:01, 24.32it/s, now=None]
# t:  89%|████████▉ | 268/300 [00:09<00:01, 24.04it/s, now=None]
# t:  90%|█████████ | 271/300 [00:09<00:01, 24.74it/s, now=None]
# t:  91%|█████████▏| 274/300 [00:09<00:01, 25.06it/s, now=None]
# t:  92%|█████████▏| 277/300 [00:09<00:00, 25.39it/s, now=None]
# t:  93%|█████████▎| 280/300 [00:09<00:00, 24.88it/s, now=None]
# t:  94%|█████████▍| 283/300 [00:10<00:00, 25.06it/s, now=None]
# t:  96%|█████████▌| 287/300 [00:10<00:00, 25.48it/s, now=None]
# t:  97%|█████████▋| 291/300 [00:10<00:00, 27.35it/s, now=None]
# t:  98%|█████████▊| 295/300 [00:10<00:00, 27.13it/s, now=None]
# t:  99%|█████████▉| 298/300 [00:10<00:00, 27.01it/s, now=None]
# t:   1%|▏         | 2/150 [20:57<00:21,  7.02it/s, now=None]
# chunk:   0%|          | 0/353 [00:00<?, ?it/s, now=None]
# chunk:   4%|▍         | 14/353 [00:00<00:02, 139.59it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready ../clips/clip8_Neymar_Jr_Best_Skills_With_Commentary__Crowd_Reaction.mp4
# Moviepy - Building video ../clips/clip9_Neymar_Jr_Best_Skills_With_Commentary__Crowd_Reaction.mp4.
# MoviePy - Writing audio in clip9_Neymar_Jr_Best_Skills_With_Commentary__Crowd_ReactionTEMP_MPY_wvf_snd.mp4
# chunk:  33%|███▎      | 115/353 [00:00<00:01, 188.21it/s, now=None]
# chunk:  71%|███████   | 249/353 [00:00<00:00, 253.51it/s, now=None]
# t:   1%|▏         | 2/150 [20:57<00:21,  7.02it/s, now=None]
# t:   0%|          | 0/400 [00:00<?, ?it/s, now=None]
# t:   0%|          | 2/400 [00:00<00:28, 14.05it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing
# t:  76%|███████▋  | 305/400 [00:13<00:05, 16.18it/s, now=None]
# t:  77%|███████▋  | 307/400 [00:13<00:05, 16.56it/s, now=None]
# t:  78%|███████▊  | 310/400 [00:13<00:05, 17.66it/s, now=None]
# t:  78%|███████▊  | 312/400 [00:13<00:05, 15.68it/s, now=None]
# t:  79%|███████▉  | 316/400 [00:13<00:04, 18.47it/s, now=None]
# t:  80%|███████▉  | 319/400 [00:13<00:04, 18.27it/s, now=None]
# t:  80%|████████  | 322/400 [00:14<00:04, 17.55it/s, now=None]
# t:  81%|████████▏ | 325/400 [00:14<00:04, 17.06it/s, now=None]
# t:  82%|████████▏ | 328/400 [00:14<00:03, 18.56it/s, now=None]
# t:  82%|████████▎ | 330/400 [00:14<00:04, 16.63it/s, now=None]
# t:  83%|████████▎ | 333/400 [00:14<00:04, 15.63it/s, now=None]
# t:  84%|████████▍ | 337/400 [00:15<00:04, 15.74it/s, now=None]
# t:  85%|████████▌ | 340/400 [00:15<00:03, 17.04it/s, now=None]
# t:  86%|████████▌ | 342/400 [00:15<00:04, 14.25it/s, now=None]
# t:  86%|████████▋ | 345/400 [00:15<00:03, 13.89it/s, now=None]
# t:  87%|████████▋ | 349/400 [00:15<00:03, 15.78it/s, now=None]
# t:  88%|████████▊ | 352/400 [00:15<00:02, 16.05it/s, now=None]
# t:  88%|████████▊ | 354/400 [00:16<00:04,  9.80it/s, now=None]
# t:  89%|████████▉ | 356/400 [00:16<00:04,  9.71it/s, now=None]
# t:  90%|████████▉ | 358/400 [00:16<00:03, 11.18it/s, now=None]
# t:  90%|█████████ | 360/400 [00:16<00:03, 10.35it/s, now=None]
# t:  90%|█████████ | 362/400 [00:17<00:03, 12.04it/s, now=None]
# t:  91%|█████████ | 364/400 [00:17<00:03, 11.00it/s, now=None]
# t:  92%|█████████▏| 366/400 [00:17<00:02, 11.68it/s, now=None]
# t:  92%|█████████▏| 368/400 [00:17<00:03, 10.66it/s, now=None]
# t:  92%|█████████▎| 370/400 [00:17<00:02, 12.11it/s, now=None]
# t:  93%|█████████▎| 373/400 [00:17<00:02, 13.35it/s, now=None]
# t:  94%|█████████▍| 376/400 [00:18<00:01, 14.99it/s, now=None]
# t:  94%|█████████▍| 378/400 [00:18<00:02,  9.68it/s, now=None]
# t:  95%|█████████▌| 381/400 [00:18<00:01, 11.66it/s, now=None]
# t:  96%|█████████▌| 383/400 [00:18<00:01, 11.65it/s, now=None]
# t:  96%|█████████▋| 385/400 [00:18<00:01, 11.75it/s, now=None]
# t:  97%|█████████▋| 388/400 [00:19<00:00, 12.88it/s, now=None]
# t:  98%|█████████▊| 390/400 [00:19<00:00, 12.04it/s, now=None]
# t:  98%|█████████▊| 392/400 [00:19<00:00, 10.89it/s, now=None]
# t:  99%|█████████▉| 395/400 [00:19<00:00, 13.41it/s, now=None]
# t:  99%|█████████▉| 397/400 [00:19<00:00, 12.60it/s, now=None]
# t: 100%|██████████| 400/400 [00:20<00:00, 12.64it/s, now=None]
# t:   1%|▏         | 2/150 [21:20<00:21,  7.02it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready ../clips/clip9_Neymar_Jr_Best_Skills_With_Commentary__Crowd_Reaction.mp4

# %% [markdown]
# ### Upload to youtube

# %%
# Get all the clips 
clip_files = sorted(os.listdir('../clips/'))
video_file = "../clips/" + clip_files[0]
print(f"Video to upload: {video_file}")
# Out:
# Video to upload: ../clips/clip0_Neymar_Jr_Best_Skills_With_Commentary__Crowd_Reaction.mp4

# %%
import upload_video
import youtube

# %%
from googleapiclient.discovery import build
from apiclient.http import MediaFileUpload
import google.oauth2.credentials
# from oauth2client.client import flow_from_clientsecrets
import json

# %%
## Datetime exploration

import datetime
# Get the current date and time
now = datetime.datetime.now()

# Calculate tomorrow's date by adding one day to the current date
tomorrow = now + datetime.timedelta(days=1)

# Create a datetime object for December 27th, 2022 at 12:00 AM
specific_datetime = datetime.datetime(2022, 12, 23, 0, 0)

# Convert the date and time to ISO 8601 format
iso_datetime = specific_datetime.isoformat()

print(iso_datetime)
# Out:
# 2022-12-23T00:00:00

# %%
# Create a YouTube service object
youtube = upload_video.get_authenticated_service()

# %%
# Set the video file and metadata
title = 'Neymar Jr crazy skills #shorts'
description = 'Neymar Jr skills and tricks #shorts'
tags = ['shorts', 'soccer', 'neymarjr']

# Create the request body
request_body = {
    'snippet': {
        'title': title,
        'description': description,
        'tags': tags
    },
    'status': {
        'privacyStatus': 'public', # private, unlisted
        # 'publishAt':  iso_datetime  # can be set if privacyStatus=private
        'selfDeclaredMadeForKids' : False
    }
}

# Create the request
request = youtube.videos().insert(
    part=",".join(request_body.keys()),
    body=request_body,
    media_body=MediaFileUpload(video_file, mimetype='video/mp4', resumable=True)
)

pprint.pprint(json.loads(request.to_json()))
# Out:
# {'_in_error_state': False,
#  'body': '{"snippet": {"title": "Neymar Jr crazy skills #shorts", '
#          '"description": "Neymar Jr skills and tricks #shorts", "tags": '
#          '["shorts", "soccer", "neymarjr"]}, "status": {"privacyStatus": '
#          '"public", "selfDeclaredMadeForKids": false}}',
#  'body_size': 225,
#  'headers': {'accept': 'application/json',
#              'accept-encoding': 'gzip, deflate',
#              'content-type': 'application/json',
#              'user-agent': '(gzip)',
#              'x-goog-api-client': 'gdcl/2.52.0 gl-python/3.6.10'},
#  'method': 'POST',
#  'methodId': 'youtube.videos.insert',
#  'response_callbacks': [],
#  'resumable': '{"_filename": '
#               '"../clips/clip0_Neymar_Jr_Best_Skills_With_Commentary__Crowd_Reaction.mp4", '
#               '"_mimetype": "video/mp4", "_chunksize": 104857600, '
#               '"_resumable": true, "_size": 1341666, "_class": '
#               '"MediaFileUpload", "_module": "googleapiclient.http"}',
#  'resumable_progress': 0,
#  'resumable_uri': None,
#  'uri': 'https://youtube.googleapis.com/upload/youtube/v3/videos?part=snippet%2Cstatus&alt=json&uploadType=resumable'}

# %%
# Execute the request
response = upload_video.resumable_upload(request)

# Print the response
print(response)
# Out:
# Uploading file...
# Video id 'CcnKNWKicXI' was successfully uploaded.
# None

# %%
# video_id = response['id']


#Note: shorts cannot have thumbnails
video_id = "gLW72MEqhZs"
thumbnail_file = "../media/images/Sparkle.png"
r = youtube.thumbnails().set(
    videoId=video_id,
    media_body=MediaFileUpload(thumbnail_file, mimetype='image/png'))
# r.execute()
# Out:
# {'etag': 'rmCN4BS7mUeeTQMzCZyPJhh-RFk',
#  'items': [{'default': {'height': 90,
#     'url': 'https://i9.ytimg.com/vi/gLW72MEqhZs/default.jpg?sqp=CNTtnp0G&rs=AOn4CLAhpABHM0GmX8SZNbRi-srS73lsbQ',
#     'width': 120},
#    'high': {'height': 360,
#     'url': 'https://i9.ytimg.com/vi/gLW72MEqhZs/hqdefault.jpg?sqp=CNTtnp0G&rs=AOn4CLDNL10sUmEy2fF8z5VEkRXr6AOrjA',
#     'width': 480},
#    'maxres': {'height': 720,
#     'url': 'https://i9.ytimg.com/vi/gLW72MEqhZs/maxresdefault.jpg?sqp=CNTtnp0G&rs=AOn4CLDbXTyRqqRH88vzkqV_Q6YwObzDMA',
#     'width': 1280},
#    'medium': {'height': 180,
#     'url': 'https://i9.ytimg.com/vi/gLW72MEqhZs/mqdefault.jpg?sqp=CNTtnp0G&rs=AOn4CLCu5HhE17nlS6DLVtCkEnkSiFfwnw',
#     'width': 320},
#    'standard': {'height': 480,
#     'url': 'https://i9.ytimg.com/vi/gLW72MEqhZs/sddefault.jpg?sqp=CNTtnp0G&rs=AOn4CLDFkRF6ratZ9dvMEDJJ-NGeob5ceA',
#     'width': 640}}],
#  'kind': 'youtube#thumbnailSetResponse'}

# %%
# !python upload_video.py --file="../clips/clip3_Neymar_Jr_Best_Skills_With_Commentary__Crowd_Reaction.mp4" \
                        --title="Neymar Jr skills #shorts" \
                       --description="Neymar Jr skills and tricks" \
                       --keywords="shorts,soccer,neymarjr" \
                       --category="22" \
                       --privacyStatus="private" \
# Out:
# Authenticated Youtube API
# request:  {"snippet": {"title": "Neymar Jr skills #shorts", "description": "Neymar Jr skills and tricks", "tags": ["shorts", "soccer", "neymarjr"], "categoryId": "22"}, "status": {"privacyStatus": "private"}}

# %% [markdown]
# ###  OpenCV

# %%
# Open the video file and get dimensions
video_capture = cv2.VideoCapture(video_path)
print(video_capture)

width = video_capture.get(cv2.CAP_PROP_FRAME_WIDTH)
height = video_capture.get(cv2.CAP_PROP_FRAME_HEIGHT)
fps =  video_capture.get(cv2.CAP_PROP_FPS)
print(f"Width: {width}, Height {height}, fps: {fps}")

# Set the output video file
fourcc = cv2.VideoWriter_fourcc(*'MP4V')
video_writer = cv2.VideoWriter(f"../media/blurred_{video_file}", fourcc, fps, (int(width), int(height)))

# %%
# OpenCV
# Loop through each frame in the video
i = 0
while False:
    
    # Read the next frame
    success, frame = video_capture.read()

    # If there are no more frames, break out of the loop
    if not success:
        break

    # Blur a section of the frame
    # x1, y1, x2, y2 = calculate_blur_region((width, height), sc_size, top_left, bottom_right)
    frame[y1:y2, x1:x2] = cv2.blur(frame[y1:y2, x1:x2], (10, 10))

    # Write the frame to the output video file
    video_writer.write(frame)
    
    if i % 1000 == 0:
        print(f"frame {i}")
    i += 1

# Release the video capture and video writer objects
video_capture.release()
video_writer.release()
